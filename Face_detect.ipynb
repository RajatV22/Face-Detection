# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# Create the haar cascade
cascPath = 'hascascades/haarcascade_frontalface_alt.xml'
# cascPath = 'detect/haarcascade_frontalface_default.xml'
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
def detect_faces_show(fpath):
    img = cv2.imread(fpath)
    # convert image to gray scale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Detect faces in the image
    faces = faceCascade.detectMultiScale(
        gray, scaleFactor=1.2,
        minNeighbors=5, minSize=(30, 30),
        flags = cv2.CASCADE_SCALE_IMAGE)
    print("Found %d faces!" % len(faces))

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 3)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
detect_faces_show('ioi2.jpg')
# Out:
# Found 11 faces!

# %%
detect_faces_show('b2.jpg')
# Out:
# Found 3 faces!

# %%
# Read the image
img1 = cv2.imread('b2.jpg')
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
