# %%
import pandas as pd
text=['This is introduction to NLP','It is likely to be useful, to people ','Machine learning is the new electrcity',\
      'There would be less hype around AI and more action going forward','python is the best tool!',\
      'R is good langauage','I like this book','I want more books like this']

#convert list to data frame
df = pd.DataFrame({'tweet':text})
print(df)
# Out:
#                                                tweet
# 0                        This is introduction to NLP
# 1              It is likely to be useful, to people
# 2             Machine learning is the new electrcity
# 3  There would be less hype around AI and more ac...
# 4                           python is the best tool!
# 5                                R is good langauage
# 6                                   I like this book
# 7                        I want more books like this

# %%
#install and import libraries
from nltk.corpus import stopwords

#remove stop words
stop = set(stopwords.words('english'))
df['tweet'] = df['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['tweet']
# Out:
# 0                                This introduction NLP
# 1                             It likely useful, people
# 2                      Machine learning new electrcity
# 3    There would less hype around AI action going f...
# 4                                    python best tool!
# 5                                     R good langauage
# 6                                          I like book
# 7                                    I want books like
# Name: tweet, dtype: object

# %%
# Create a custom lookup dictionary
lookup_dict = {'nlp':'natural language processing', 'ur':'your', "wbu" : "what about you"}

import re
#  Create a custom function for text standardization
def text_std(input_text):
    words = input_text.split()
    new_words = []
    for word in words:
        word = re.sub(r'[^\w\s]','',word)
        if word.lower() in lookup_dict:
            word = lookup_dict[word.lower()]
            new_words.append(word)
            new_text = " ".join(new_words)
    return new_text

#  Run the text_std function
text_std("I like nlp it's ur choice")
# Out:
# 'natural language processing your'

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\rvsha\anaconda3\lib\site-packages (from textblob) (3.6.5)
# Requirement already satisfied: click in c:\users\rvsha\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: joblib in c:\users\rvsha\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rvsha\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\rvsha\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: colorama in c:\users\rvsha\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1

# %%
# Read/create the text data
text=['Introduction to NLP','It is lik to be useful, to people ','Machine learning is the new electrcity',\
      'R is good langauage','I like this book','I want many mre books like this']
df = pd.DataFrame({'tweet':text})
print(df)
# Out:
#                                     tweet
# 0                     Introduction to NLP
# 1      It is lik to be useful, to people
# 2  Machine learning is the new electrcity
# 3                     R is good langauage
# 4                        I like this book
# 5         I want many mre books like this

# %%
from textblob import TextBlob

df['tweet'].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0                        Introduction to NLP
# 1        It is like to be useful, to people
# 2    Machine learning is the new electricity
# 3                         R is good language
# 4                           I like this book
# 5            I want many are books like this
# Name: tweet, dtype: object

# %%
# !pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py): started
#   Building wheel for autocorrect (setup.py): finished with status 'done'
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622381 sha256=e1205df97e8758ffc0eb650efa25e6ad8b5790a75d787bf741786a19c3e04395
#   Stored in directory: c:\users\rvsha\appdata\local\pip\cache\wheels\ab\0f\23\3c010c3fd877b962146e7765f9e9b08026cac8b035094c5750
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
from autocorrect import Speller
spell = Speller()
print(spell(u'mussage'))
print(spell(u'sirvice'))
# Out:
# message
# service

# %%
#Let's create a list of strings and assign it to a variable. 
text=['This is introduction to NLP','It is likely to be useful, to people ','Machine learning is the new electrcity',\
      'There would be less hype around AI and more action going forward','python is the best tool!',\
      'R is good langauage','I like this book','I want more books like this']

#convert list to dataframe

df = pd.DataFrame({'tweet':text})
print(df)
# Out:
#                                                tweet
# 0                        This is introduction to NLP
# 1              It is likely to be useful, to people
# 2             Machine learning is the new electrcity
# 3  There would be less hype around AI and more ac...
# 4                           python is the best tool!
# 5                                R is good langauage
# 6                                   I like this book
# 7                        I want more books like this

# %%
from textblob import TextBlob
TextBlob(df['tweet'][3]).words
# Out:
# WordList(['There', 'would', 'be', 'less', 'hype', 'around', 'AI', 'and', 'more', 'action', 'going', 'forward'])

# %%
#create data
mystring = "My favorite animal is cat"

#using split function from python
mystring.split()
# Out:
# ['My', 'favorite', 'animal', 'is', 'cat']

# %%
text=['I like fishing','I eat fish','There are many fishes in pound']

#convert list to dataframe
df = pd.DataFrame({'tweet':text})
print(df)
# Out:
#                             tweet
# 0                  I like fishing
# 1                      I eat fish
# 2  There are many fishes in pound

# %%
from nltk.stem import PorterStemmer

st = PorterStemmer()
df['tweet'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0                     i like fish
# 1                      i eat fish
# 2    there are mani fish in pound
# Name: tweet, dtype: object

# %%
text=['I like fishing','I eat fish','There are many fishes in pound', 'leaves and leaf']

#convert list to dataframe
df = pd.DataFrame({'tweet':text})

print(df)
# Out:
#                             tweet
# 0                  I like fishing
# 1                      I eat fish
# 2  There are many fishes in pound
# 3                 leaves and leaf

# %%
from textblob import Word
#Code for lemmatize
df['tweet'] = df['tweet'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df['tweet']
# Out:
# 0                  I like fishing
# 1                      I eat fish
# 2    There are many fish in pound
# 3                   leaf and leaf
# Name: tweet, dtype: object

# %%
import nltk
nltk.download('webtext')
# Out:
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\rvsha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\webtext.zip.
# True

# %%
from nltk.corpus import webtext
wt_sentences = webtext.sents('firefox.txt')
wt_words = webtext.words('firefox.txt')

# Import Library for computing frequency 
from nltk.probability import FreqDist
import string

# Count the number of words 
len(wt_sentences)
# Out:
# 1142

# %%
len(wt_words)
# Out:
# 102457

# %%
# Generating frequency for all the words:
frequency_dist = FreqDist(wt_words) 
frequency_dist
# Out:
# FreqDist({'.': 2428, 'in': 2203, 'to': 2130, '"': 1971, 'the': 1762, "'": 1507, 'not': 1472, '-': 1372, 'when': 1255, 'on': 1193, ...})

# %%
sorted_frequency_dist =sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)
sorted_frequency_dist
# Out:
# ['.',
#  'in',
#  'to',
#  '"',
#  'the',
#  "'",
#  'not',
#  '-',
#  'when',
#  'on',
#  'a',
#  'is',
#  't',
#  'and',
#  'of',
#  '(',
#  'page',
#  'for',
#  'with',
#  ')',
#  'window',
#  'Firefox',
#  'does',
#  'from',
#  'open',
#  ':',
#  'menu',
#  'should',
#  'bar',
#  'tab',
#  'doesn',
#  'after',
#  'Firebird',
#  'new',
#  'work',
#  'browser',
#  'if',
#  'be',
#  '0',
#  'toolbar',
#  'button',
#  'bookmarks',
#  'dialog',
#  'bookmark',
#  'as',
#  'file',
#  'URL',
#  'download',
#  'crashes',
#  'I',
#  'no',
#  'text',
#  'are',
#  'or',
#  'up',
#  'crash',
#  'click',
#  'tabs',
#  'Bookmarks',
#  'link',
#  '/',
#  'firefox',
#  'manager',
#  '+',
#  'using',
#  'it',
#  'Mozilla',
#  'default',
#  'error',
#  'all',
#  'an',
#  'clicking',
#  's',
#  'windows',
#  'search',
#  'folder',
#  ']',
#  'Phoenix',
#  '1',
#  'at',
#  'icon',
#  'Manager',
#  'by',
#  'this',
#  'site',
#  'can',
#  'files',
#  'Page',
#  'fails',
#  'causes',
#  'use',
#  'close',
#  '[',
#  'opening',
#  'Toolbar',
#  'Add',
#  'has',
#  'Bookmark',
#  'right',
#  'display',
#  'down',
#  'that',
#  'theme',
#  'box',
#  'Download',
#  '9',
#  'The',
#  'pages',
#  'firebird',
#  'only',
#  'url',
#  'while',
#  'have',
#  'image',
#  'links',
#  'When',
#  'location',
#  'Crash',
#  'option',
#  'scroll',
#  'load',
#  'cannot',
#  'Options',
#  'address',
#  '>',
#  'Can',
#  'start',
#  'password',
#  'com',
#  'do',
#  '->',
#  'extension',
#  'install',
#  'back',
#  'buttons',
#  'history',
#  'loading',
#  'don',
#  'you',
#  'web',
#  'form',
#  'instead',
#  'wrong',
#  'No',
#  'show',
#  'mouse',
#  'build',
#  'sidebar',
#  'about',
#  'focus',
#  'will',
#  'http',
#  '://',
#  'set',
#  'broken',
#  'Windows',
#  'popup',
#  'some',
#  'icons',
#  'opens',
#  'drop',
#  'context',
#  'into',
#  'autocomplete',
#  '8',
#  'preferences',
#  'missing',
#  'screen',
#  'one',
#  'save',
#  'Open',
#  'field',
#  'print',
#  'Ctrl',
#  'working',
#  'images',
#  'profile',
#  'other',
#  'options',
#  'mozilla',
#  'add',
#  'New',
#  'Find',
#  'Browser',
#  'startup',
#  'any',
#  'change',
#  'size',
#  'list',
#  'javascript',
#  'opened',
#  'first',
#  'type',
#  'user',
#  'too',
#  'trying',
#  'but',
#  '2',
#  'like',
#  '<',
#  'extensions',
#  'displayed',
#  'multiple',
#  'Save',
#  'phoenix',
#  'selected',
#  'Cannot',
#  'time',
#  'i',
#  'won',
#  'shows',
#  'properly',
#  'over',
#  'appears',
#  'view',
#  'Error',
#  'X',
#  'name',
#  'correctly',
#  'always',
#  ';',
#  'left',
#  'item',
#  'hangs',
#  'appear',
#  'background',
#  'menus',
#  'UI',
#  'directory',
#  'input',
#  'application',
#  'themes',
#  'version',
#  'message',
#  'same',
#  'blank',
#  'View',
#  'Web',
#  'www',
#  'File',
#  'middle',
#  'Tab',
#  'OS',
#  'even',
#  'go',
#  'folders',
#  'scrolling',
#  'html',
#  'keyboard',
#  'off',
#  'without',
#  'non',
#  'Tools',
#  'Menu',
#  'line',
#  'my',
#  'Preferences',
#  'proxy',
#  'saved',
#  'out',
#  '6',
#  'sites',
#  'IE',
#  'Clicking',
#  'select',
#  'content',
#  'Search',
#  'home',
#  'than',
#  'update',
#  'shortcut',
#  'items',
#  'get',
#  'under',
#  'source',
#  'preview',
#  'current',
#  'closing',
#  '&',
#  'find',
#  'Javascript',
#  'clicked',
#  'cookies',
#  '|',
#  'plugin',
#  'empty',
#  'key',
#  'History',
#  'remove',
#  'running',
#  '...',
#  'disabled',
#  'longer',
#  'support',
#  'dropdown',
#  'status',
#  'installer',
#  'installing',
#  '7',
#  'works',
#  'displays',
#  'document',
#  'allow',
#  'JavaScript',
#  'Password',
#  'shown',
#  'After',
#  'top',
#  'downloads',
#  'OK',
#  'last',
#  'mode',
#  'Folder',
#  'more',
#  'enter',
#  'drag',
#  'website',
#  'freezes',
#  'wheel',
#  'login',
#  'launch',
#  'another',
#  'needs',
#  'bug',
#  '3',
#  'About',
#  'ctrl',
#  'being',
#  'Unable',
#  'Print',
#  'function',
#  'Installer',
#  'Text',
#  'Help',
#  'used',
#  'disable',
#  'Extension',
#  'js',
#  'Use',
#  'problem',
#  'try',
#  'installed',
#  'downloading',
#  'XML',
#  'make',
#  'Need',
#  '%',
#  'settings',
#  'Linux',
#  'As',
#  'cursor',
#  'enabled',
#  'still',
#  'Java',
#  'run',
#  'closed',
#  'found',
#  '::',
#  'small',
#  'builds',
#  'main',
#  'chrome',
#  'Tabs',
#  'system',
#  'access',
#  'Mac',
#  '=',
#  'its',
#  'installation',
#  '[@',
#  'browsing',
#  'slow',
#  'Profile',
#  'breaks',
#  'Location',
#  '()',
#  'Bar',
#  'flash',
#  'Wrong',
#  'certain',
#  'Image',
#  'Default',
#  'changes',
#  'loaded',
#  'two',
#  'characters',
#  'pop',
#  'URLs',
#  'Link',
#  'selection',
#  'server',
#  'loads',
#  'between',
#  'information',
#  'CPU',
#  'switching',
#  'code',
#  'style',
#  'then',
#  'auto',
#  'import',
#  '4',
#  'Window',
#  'incorrectly',
#  'command',
#  'was',
#  'Not',
#  '..."',
#  'gets',
#  'webpage',
#  'complete',
#  'CSS',
#  'FireFox',
#  'customize',
#  'second',
#  '!',
#  'large',
#  'via',
#  'delete',
#  'Sidebar',
#  'exe',
#  'tag',
#  'me',
#  'Internet',
#  'Popup',
#  'java',
#  'changing',
#  'entry',
#  'different',
#  'way',
#  'Dialog',
#  'Flash',
#  'until',
#  'full',
#  'stop',
#  'pref',
#  'selecting',
#  'connection',
#  'problems',
#  'nothing',
#  'dll',
#  'there',
#  'already',
#  'remember',
#  'through',
#  'boxes',
#  'restart',
#  'incorrect',
#  '5',
#  'cache',
#  'homepage',
#  'Info',
#  'In',
#  'very',
#  'rendering',
#  'warning',
#  'which',
#  'cookie',
#  'stops',
#  'results',
#  'arrow',
#  'org',
#  'preference',
#  'character',
#  'Downloads',
#  'mail',
#  'title',
#  'data',
#  'XP',
#  'Form',
#  'available',
#  'Customize',
#  'Autocomplete',
#  'Remove',
#  'Make',
#  '?',
#  'clear',
#  'times',
#  'copy',
#  'Source',
#  'sometimes',
#  'google',
#  'request',
#  'HTML',
#  'makes',
#  'Theme',
#  'submit',
#  'fields',
#  'create',
#  'starting',
#  'This',
#  'before',
#  'them',
#  'Extensions',
#  'Opening',
#  'uses',
#  'prefs',
#  'visible',
#  'info',
#  'gives',
#  'alert',
#  'old',
#  'properties',
#  'keys',
#  'goes',
#  'lost',
#  '="',
#  'blocking',
#  'favicon',
#  'disappear',
#  'toolbars',
#  'doesnt',
#  'upon',
#  'viewing',
#  'automatically',
#  'need',
#  'hang',
#  'switch',
#  'showing',
#  'Back',
#  'each',
#  'external',
#  'Home',
#  'refresh',
#  'string',
#  'All',
#  'blocked',
#  '100',
#  'during',
#  'setting',
#  'unable',
#  'many',
#  'Right',
#  'Thunderbird',
#  'navigation',
#  'move',
#  'every',
#  'space',
#  'downloaded',
#  'contains',
#  'Middle',
#  'double',
#  'active',
#  'Option',
#  'disk',
#  'If',
#  'Address',
#  'scrollbar',
#  'expand',
#  'session',
#  'Images',
#  'Go',
#  'completely',
#  'personal',
#  'color',
#  'fonts',
#  'forms',
#  'updated',
#  'where',
#  'value',
#  'closes',
#  'prompt',
#  'monitor',
#  'within',
#  'desktop',
#  'nightly',
#  'render',
#  'linux',
#  'reload',
#  'Yahoo',
#  'release',
#  'deleted',
#  'end',
#  'passwords',
#  'app',
#  'inside',
#  'next',
#  'Context',
#  'forward',
#  'possible',
#  'part',
#  'added',
#  'textbox',
#  'feature',
#  'Show',
#  'just',
#  'Themes',
#  'Auto',
#  'Alt',
#  'Downloading',
#  'program',
#  'help',
#  'Enter',
#  'A',
#  'so',
#  'been',
#  'long',
#  'plugins',
#  'isn',
#  'choose',
#  'RFE',
#  'shortcuts',
#  'Toolbars',
#  'CTRL',
#  'itself',
#  'Update',
#  'usage',
#  'ability',
#  'Implement',
#  'order',
#  'ignored',
#  'area',
#  'twice',
#  'position',
#  'Preview',
#  'disappears',
#  'existing',
#  'Mouse',
#  'Click',
#  'behaviour',
#  'edit',
#  'e',
#  'cause',
#  'see',
#  'displaying',
#  'again',
#  'filename',
#  'deleting',
#  'https',
#  'local',
#  'cust',
#  'adding',
#  'remote',
#  'table',
#  'accessing',
#  'dragging',
#  'Ability',
#  'typing',
#  'network',
#  'action',
#  'Site',
#  'immediately',
#  'starts',
#  'created',
#  'certificate',
#  'saving',
#  'fail',
#  'font',
#  'handling',
#  'popups',
#  'Crashes',
#  'enable',
#  'due',
#  'css',
#  'cancel',
#  'able',
#  'hidden',
#  'panel',
#  'Close',
#  'specific',
#  'Set',
#  'HTTP',
#  'PDF',
#  'failed',
#  'email',
#  'Change',
#  'previous',
#  'could',
#  'stored',
#  'Start',
#  'net',
#  'Shift',
#  'send',
#  'rendered',
#  'User',
#  'checkbox',
#  'typed',
#  'Using',
#  'config',
#  'Cookie',
#  'checked',
#  'memory',
#  'above',
#  'resize',
#  'imported',
#  'number',
#  'failure',
#  'tooltip',
#  'now',
#  'contents',
#  'pdf',
#  'Full',
#  'Icon',
#  'functionality',
#  'Double',
#  'It',
#  're',
#  'username',
#  'entered',
#  'bad',
#  'href',
#  'event',
#  'visiting',
#  'autoscroll',
#  'changed',
#  'Don',
#  'removed',
#  'stay',
#  'script',
#  'attempting',
#  'tree',
#  'Privacy',
#  'x',
#  'effect',
#  'single',
#  'state',
#  'control',
#  'exception',
#  'fullscreen',
#  'creates',
#  'shift',
#  'responding',
#  'path',
#  'present',
#  'Google',
#  'dialogs',
#  'crashed',
#  'anymore',
#  'plug',
#  'locks',
#  'frame',
#  'console',
#  'zip',
#  '*',
#  'secure',
#  'seems',
#  'Personal',
#  'Scroll',
#  'respond',
#  'containing',
#  'launching',
#  'place',
#  'going',
#  'overflow',
#  'Get',
#  'black',
#  'Selecting',
#  'side',
#  'keyword',
#  'loses',
#  'behavior',
#  'accept',
#  'column',
#  '--',
#  'bars',
#  'shouldn',
#  'says',
#  'entries',
#  'printing',
#  'websites',
#  'On',
#  'header',
#  'never',
#  'Security',
#  'Screen',
#  'xul',
#  'jar',
#  'blocker',
#  'applet',
#  'bottom',
#  'width',
#  'paste',
#  'what',
#  'Cancel',
#  'Allow',
#  'anything',
#  'Display',
#  'Install',
#  'Manage',
#  'away',
#  'pressing',
#  'Menus',
#  'once',
#  'Request',
#  'ignores',
#  'specified',
#  'returns',
#  'exit',
#  'include',
#  'Build',
#  'tags',
#  'random',
#  'parsing',
#  '\\',
#  'tabbed',
#  'MozillaFirebird',
#  'attribute',
#  'stylesheet',
#  'DOM',
#  'Edit',
#  'Bad',
#  'authentication',
#  'Mail',
#  'cut',
#  'Icons',
#  'domain',
#  'Some',
#  'block',
#  'tools',
#  'Should',
#  'object',
#  'w',
#  'loop',
#  'takes',
#  'yahoo',
#  'Advanced',
#  'Font',
#  'Type',
#  'frames',
#  'Explorer',
#  'types',
#  'process',
#  'Desktop',
#  'correct',
#  'Enable',
#  'tries',
#  'take',
#  'Please',
#  'renders',
#  'sort',
#  'applications',
#  'With',
#  'Cookies',
#  'Plugin',
#  'favicons',
#  'Problem',
#  'Incorrect',
#  'Create',
#  'fine',
#  'check',
#  'pops',
#  'keeps',
#  'defined',
#  'freeze',
#  'several',
#  '")',
#  'needed',
#  'MS',
#  'XPI',
#  'Installing',
#  'root',
#  'port',
#  'elements',
#  'profiles',
#  'notification',
#  'entering',
#  'keywords',
#  'target',
#  'rdf',
#  'Inspector',
#  'called',
#  'made',
#  'customization',
#  'throbber',
#  'fix',
#  'Navigation',
#  'restore',
#  'standard',
#  'Keyboard',
#  'security',
#  'hide',
#  'invalid',
#  'look',
#  '10',
#  'defaults',
#  'scrollbars',
#  'big',
#  'looks',
#  'latest',
#  'engine',
#  '."',
#  '".',
#  'dual',
#  'undefined',
#  'gtk2',
#  'exist',
#  'listed',
#  '("',
#  'embedded',
#  'FB',
#  'Feature',
#  'given',
#  'collapse',
#  'though',
#  'Missing',
#  'Import',
#  'becomes',
#  'arrows',
#  'urlbar',
#  'os',
#  'Do',
#  'strange',
#  'sheet',
#  'updates',
#  'pointer',
#  'brings',
#  'trunk',
#  'Status',
#  'setup',
#  'extra',
#  'Load',
#  'SSL',
#  'Does',
#  'remains',
#  'want',
#  'Links',
#  'spaces',
#  'quit',
#  'turn',
#  'Clear',
#  'word',
#  'wont',
#  'hand',
#  'Select',
#  'Empty',
#  'FTP',
#  'seconds',
#  'visited',
#  'Printing',
#  'reset',
#  'Netscape',
#  'element',
#  'xml',
#  'result',
#  'started',
#  'branch',
#  'Button',
#  'mac',
#  'updating',
#  'separator',
#  'manage',
#  'high',
#  'Quick',
#  'implement',
#  'would',
#  'refuses',
#  'customizing',
#  'give',
#  'group',
#  'configuration',
#  'editing',
#  'moving',
#  'Support',
#  'Drag',
#  'because',
#  'mailto',
#  'pressed',
#  'own',
#  'disappeared',
#  'internet',
#  'border',
#  'editor',
#  'client',
#  'general',
#  'resizing',
#  'also',
#  'unless',
#  'There',
#  'stays',
#  'based',
#  'alternate',
#  'become',
#  'read',
#  'finished',
#  'alt',
#  'named',
#  'components',
#  'Parsing',
#  'play',
#  'instance',
#  'choosing',
#  'remembered',
#  'behind',
#  'Saved',
#  'animated',
#  'secondary',
#  'attempt',
#  'engines',
#  'XUL',
#  '#',
#  'patch',
#  'progress',
#  'JS',
#  'hover',
#  'colors',
#  'building',
#  'General',
#  'how',
#  'removing',
#  'F',
#  ...]

# %%
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])

frequency_dist = FreqDist(large_words)
frequency_dist.plot(20,cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
